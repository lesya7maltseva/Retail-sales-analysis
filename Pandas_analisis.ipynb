# %% [markdown]
# <a href="https://colab.research.google.com/github/lesya7maltseva/Retail-sales-analysis/blob/main/Pandas_analisis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#считываем файл с заказами
df_orders = pd.read_excel('/content/orders.xlsx')
df_orders.head(10)
# Out:
#      order_id         accepted_at  product_id  quantity  regular_price  price  \
# 0  1517514900 2022-01-13 16:48:19       17122         1            169    169
# 1  1517430051 2022-01-13 16:46:53       17122         1            169    169
# 2  1517578174 2022-01-13 18:12:30       17122         1            169    169
# 3  1517466327 2022-01-13 15:11:12       22199         1            219    219
# 4  1517429157 2022-01-13 19:15:59       22199         1            219    219
# 5  1517416615 2022-01-13 10:39:06       22199         1            219    219
# 6  1517577392 2022-01-13 11:50:14       22199         1            219    219
# 7  1517443550 2022-01-13 08:08:04        3414         6             27     27
# 8  1517623373 2022-01-13 16:17:00        3414         3             27     27
# 9  1517496176 2022-01-13 20:59:03       47819         1            119    119
#
#    cost_price
# 0          74
# 1          74
# 2          74
# 3         130
# 4         130
# 5         130
# 6         130
# 7          22
# 8          22
# 9          65

# %%
#проверяем на количество строк - во всех столбцах одинаковое количество - пропусков нет
df_orders.describe()
# Out:
#            order_id                    accepted_at     product_id    quantity  \
# count  3.323000e+03                           3323    3323.000000  3323.00000
# mean   1.517529e+09  2022-01-13 16:02:37.557628416   22961.379175     1.23533
# min    1.517207e+09            2022-01-13 08:00:30      23.000000     1.00000
# 25%    1.517454e+09            2022-01-13 12:50:33    6008.000000     1.00000
# 50%    1.517524e+09            2022-01-13 16:26:22   12114.000000     1.00000
# 75%    1.517605e+09            2022-01-13 19:22:00   30321.500000     1.00000
# max    1.517855e+09            2022-01-13 22:58:29  120497.000000    12.00000
# std    1.029182e+05                            NaN   25476.196162     0.78861
#
#        regular_price        price   cost_price
# count    3323.000000  3323.000000  3323.000000
# mean      139.828167   130.645501    81.106229
# min        11.000000     4.000000     7.000000
# 25%        77.000000    72.000000    42.000000
# 50%       117.000000   109.000000    67.000000
# 75%       179.000000   165.000000   101.000000
# max      1797.000000  1797.000000   808.000000
# std       104.195194    96.328751    61.505484

# %%
#считываем файл с категориями товаров
df_products = pd.read_excel('/content/products.xlsx', names=['product_id',	'category','subcategory', 'name'])
#проверяем на количество строк - в столбце name 39940 значений. Интересно почему не везде прописано название продукта - в некоторых только id, категория и подкатегория.
df_products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40152 entries, 0 to 40151
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   product_id   40152 non-null  int64
#  1   category     40152 non-null  object
#  2   subcategory  40152 non-null  object
#  3   name         39940 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 1.2+ MB

# %%
df_products.head(10)
# Out:
#    product_id                     category  \
# 0           1                      Гигиена
# 1           2  Мучные кондитерские изделия
# 2           3           Мясная гастрономия
# 3           4                          Чай
# 4           5       Безалкогольные напитки
# 5           6           Молочная продукция
# 6           7       Замороженная продукция
# 7           8           Молочная продукция
# 8           9         Кондитерские изделия
# 9          10                 Свежие овощи
#
#                            subcategory  \
# 0                               Бритье
# 1          Мучные кондитерские изделия
# 2                   Сосиски, сардельки
# 3                           Черный чай
# 4                    Соковая продукция
# 5                              Йогурты
# 6           Замороженные полуфабрикаты
# 7  Кисломолочные традиционные продукты
# 8     Современные кондитерские изделия
# 9    Корнеплоды, зелень и прочие овощи
#
#                                                 name
# 0  Кассеты для бритья Gillette Fusion ProGlide Po...
# 1                                  Печенье Бодрость
# 2                               Сосиски Стародворье
# 3                                       Чай Азерчай
# 4                                        Морс Valio
# 5                        Питьевой биойогурт Слобода
# 6                           Чебупели сочные с мясом
# 7                             Сметана Простоквашино
# 8                           Батончик Nestle Fitness
# 9                                            Шпинат

# %%
#выбираем строки со значением null в задании этого не было,сделала просто для практики
df_products[df_products.isna().any(axis=1)]
# Out:
#        product_id                      category  \
# 821           822        Безалкогольные напитки
# 1372         1373                          Сыры
# 2439         2442                 Бытовая химия
# 3277         3281                       Гигиена
# 3440         3444  Хлеб и хлебобулочные изделия
# ...           ...                           ...
# 39801      104104                   Кофе, какао
# 39866      104714        Безалкогольные напитки
# 40057      107597                         Рынок
# 40065      107897            Молочная продукция
# 40121      111257                         Снэки
#
#                                subcategory name
# 821                          Воды питьевые  NaN
# 1372                           Мягкие сыры  NaN
# 2439                   Средства для уборки  NaN
# 3277               Средства личной гигиены  NaN
# 3440          Хлеб и хлебобулочные изделия  NaN
# ...                                    ...  ...
# 39801                                 Кофе  NaN
# 39866                              Напитки  NaN
# 40057                           Рынок.Сыры  NaN
# 40065  Кисломолочные традиционные продукты  NaN
# 40121                        Снэки соленые  NaN
#
# [212 rows x 4 columns]

# %%
# соединяем по ключу product_id
df_merged_raw = df_orders.merge(df_products, on='product_id', how='left')

# %%
df_merged_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3323 entries, 0 to 3322
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       3323 non-null   int64
#  1   accepted_at    3323 non-null   datetime64[ns]
#  2   product_id     3323 non-null   int64
#  3   quantity       3323 non-null   int64
#  4   regular_price  3323 non-null   int64
#  5   price          3323 non-null   int64
#  6   cost_price     3323 non-null   int64
#  7   category       3018 non-null   object
#  8   subcategory    3018 non-null   object
#  9   name           3010 non-null   object
# dtypes: datetime64[ns](1), int64(6), object(3)
# memory usage: 259.7+ KB

# %% [markdown]
# В некоторых строках таблицы при лефт-джойне в значении категорий, подкатегорий, названия появляется NaN.Таких значений 305. Приняла решение оставить и переименовать в unknown, поскольку по деньгам эти позиции числятся

# %%
df_merged_raw = df_merged_raw.fillna('unknown')

# %%
df_merged_raw['accepted_at'] = pd.to_datetime(df_merged_raw['accepted_at']).dt.date
df_merged_raw.head(3)
# Out:
#      order_id accepted_at  product_id  quantity  regular_price  price  \
# 0  1517514900  2022-01-13       17122         1            169    169
# 1  1517430051  2022-01-13       17122         1            169    169
# 2  1517578174  2022-01-13       17122         1            169    169
#
#    cost_price            category             subcategory  \
# 0          74  Рыбная гастрономия  Нерыбные продукты моря
# 1          74  Рыбная гастрономия  Нерыбные продукты моря
# 2          74  Рыбная гастрономия  Нерыбные продукты моря
#
#                          name
# 0  Крабовые палочки Меридиан
# 1  Крабовые палочки Меридиан
# 2  Крабовые палочки Меридиан

# %% [markdown]
# # **Самая ходовая товарная группа**

# %%
df_most_pupular = df_merged_raw.groupby('category').agg({'quantity':'sum'}).sort_values(by = 'quantity',ascending=False).reset_index()
df_most_pupular
# Out:
#                         category  quantity
# 0         Безалкогольные напитки       534
# 1             Молочная продукция       483
# 2                        unknown       373
# 3                   Свежие овощи       262
# 4                      Кулинария       250
# 5                        Бакалея       239
# 6   Хлеб и хлебобулочные изделия       218
# 7                          Снэки       212
# 8                  Свежие фрукты       184
# 9         Замороженная продукция       175
# 10          Кондитерские изделия       138
# 11   Мучные кондитерские изделия       124
# 12                          Сыры       114
# 13        Продукция для животных       113
# 14            Мясная гастрономия       112
# 15               Детское питание        96
# 16                         Птица        90
# 17                       Гигиена        77
# 18     Консервированные продукты        74
# 19            Рыбная гастрономия        44
# 20                           Чай        40
# 21                 Яичные товары        40
# 22                          Мясо        29
# 23                          Уход        24
# 24                 Бытовая химия        23
# 25                   Кофе, какао        21
# 26                          Рыба         8
# 27      Детство (Гигиена и Уход)         6
# 28           Специальное питание         2

# %%
#создаем обасть графика
fig, ax = plt.subplots(figsize = (13,9))

# добавим цвета на график:
max_color = 'orchid'
others = 'gray'
# безалкогольные напитки лидируют с большим отрывом, поэтому цветом выделила их
df_most_pupular['colour'] = df_most_pupular['quantity'].apply(lambda x: max_color if x >= 400 else others)
# горизонтальный барчар
bars = ax.barh(df_most_pupular['category'], df_most_pupular['quantity'], color = df_most_pupular['colour'])
ax.xaxis.set_visible(False)
ax.set_title('Самая ходовая товарная группа', fontsize=16,
              fontweight='bold', loc = 'left', pad = 15.0)
# подпишем оси
ax.set_xlabel('Количество проданного товара в штуках')
ax.set_ylabel('Наименование категории')
ax.grid(True, color = 'gray', linestyle = '-.', linewidth = 0.8, alpha = 0.2)

#чтоб не изменять сортировку в датафрейме изменим на графике
ax.invert_yaxis()
ax.bar_label(bars, padding = 5)

plt.show()

# %% [markdown]
# # **Распределение продаж по подкатегориям**

# %%
df_merged_raw.groupby(['category','subcategory']).agg({'quantity':'sum'}).reset_index()
# Out:
#                          category                   subcategory  quantity
# 0                         unknown                       unknown       373
# 1                         Бакалея                  Все для суши         9
# 2                         Бакалея        Зерновые для завтраков        24
# 3                         Бакалея       Ингредиенты для готовки        21
# 4                         Бакалея                Крупы, бобовые        30
# ..                            ...                           ...       ...
# 96   Хлеб и хлебобулочные изделия  Хлеб и хлебобулочные изделия       218
# 97                            Чай                   Зеленый чай         7
# 98                            Чай                Чайные напитки         7
# 99                            Чай                    Черный чай        26
# 100                 Яичные товары                  Яйцо куриное        40
#
# [101 rows x 3 columns]

# %% [markdown]
# # **Найти средний чек в заданную дату**
# 13.01.2022

# %%
# на случай если надо выбрать дату, но в данном случае не надо =_=
df_merged_raw.loc[df_merged_raw['accepted_at'] == pd.to_datetime('2022-01-13').date()]
# Out:
#         order_id accepted_at  product_id  quantity  regular_price  price  \
# 0     1517514900  2022-01-13       17122         1            169    169
# 1     1517430051  2022-01-13       17122         1            169    169
# 2     1517578174  2022-01-13       17122         1            169    169
# 3     1517466327  2022-01-13       22199         1            219    219
# 4     1517429157  2022-01-13       22199         1            219    219
# ...          ...         ...         ...       ...            ...    ...
# 3318  1517405750  2022-01-13       79337         2            105    105
# 3319  1517676281  2022-01-13       79337         1            105    105
# 3320  1517545392  2022-01-13       11897         1            513    513
# 3321  1517658904  2022-01-13        6392         2             79     79
# 3322  1517626668  2022-01-13        6392         1             79     79
#
#       cost_price                     category             subcategory  \
# 0             74           Рыбная гастрономия  Нерыбные продукты моря
# 1             74           Рыбная гастрономия  Нерыбные продукты моря
# 2             74           Рыбная гастрономия  Нерыбные продукты моря
# 3            130                         Сыры             Мягкие сыры
# 4            130                         Сыры             Мягкие сыры
# ...          ...                          ...                     ...
# 3318          54       Замороженная продукция               Мороженое
# 3319          54       Замороженная продукция               Мороженое
# 3320         392       Продукция для животных        Товары для кошек
# 3321          45  Мучные кондитерские изделия                  Хлебцы
# 3322          45  Мучные кондитерские изделия                  Хлебцы
#
#                             name
# 0     Крабовые палочки Меридиан
# 1     Крабовые палочки Меридиан
# 2     Крабовые палочки Меридиан
# 3                   Сыр Самокат
# 4                   Сыр Самокат
# ...                          ...
# 3318           Мороженое Магнат
# 3319           Мороженое Магнат
# 3320           Корм Perfect Fit
# 3321          Хлебцы Dr. Korner
# 3322          Хлебцы Dr. Korner
#
# [3323 rows x 10 columns]

# %%
AOV = (
    df_merged_raw
    .groupby('order_id')['price']
    .sum()
    .reset_index()
    ['price'].mean()
    .round(2))
print(f"Сумма среднего чека составляет: {AOV} руб.")
# Out:
# Сумма среднего чека составляет: 798.04 руб.

# %% [markdown]
# # **Доля промо в заданной категории**
#
# категория - "Сыры"
# <br>Когда товар продается по промо-акции, его базовая цена не совпадает с фактической ценой

# %%
df_cheese = df_merged_raw.loc[df_merged_raw['category'] == 'Сыры']

# %%
#df_cheese['promo'] = np.where(df_cheese['regular_price'] != df_cheese['price'], 'promo', 'not') - SettingWithCopyWarning выдает
#df_cheese['promo'] = df_cheese.apply(lambda x: x['regular_price'] - x['price'], axis=1)
#df_cheese['promo'] = df_cheese['regular_price'].sub(df_cheese['price'], axis=0)

# %%
df_cheese
# Out:
#         order_id accepted_at  product_id  quantity  regular_price  price  \
# 3     1517466327  2022-01-13       22199         1            219    219
# 4     1517429157  2022-01-13       22199         1            219    219
# 5     1517416615  2022-01-13       22199         1            219    219
# 6     1517577392  2022-01-13       22199         1            219    219
# 64    1517374975  2022-01-13        2922         1            239    239
# ...          ...         ...         ...       ...            ...    ...
# 3231  1517418098  2022-01-13        8139         1            180    180
# 3232  1517332171  2022-01-13        8139         1            180    180
# 3248  1517631130  2022-01-13       33930         1            222    222
# 3249  1517293568  2022-01-13       33930         1            222    222
# 3250  1517662947  2022-01-13       33930         1            222    222
#
#       cost_price category            subcategory                      name
# 3            130     Сыры            Мягкие сыры              Сыр Самокат
# 4            130     Сыры            Мягкие сыры              Сыр Самокат
# 5            130     Сыры            Мягкие сыры              Сыр Самокат
# 6            130     Сыры            Мягкие сыры              Сыр Самокат
# 64           136     Сыры            Мягкие сыры  Сыр Страчателла Самокат
# ...          ...      ...                    ...                       ...
# 3231         104     Сыры  Твердые сычужные сыры                       NaN
# 3232         104     Сыры  Твердые сычужные сыры                       NaN
# 3248         127     Сыры            Мягкие сыры               Сыр Pretto
# 3249         127     Сыры            Мягкие сыры               Сыр Pretto
# 3250         127     Сыры            Мягкие сыры               Сыр Pretto
#
# [106 rows x 10 columns]

# %%
df_cheese['promo'] = np.where(df_cheese['regular_price'] != df_cheese['price'], 'promo', 'regular')
# Out:
# <ipython-input-81-076e059e9c26>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cheese['promo'] = np.where(df_cheese['regular_price'] != df_cheese['price'], 'promo', 'regular')

# %%
# предварительно подготовим данные для pychart
promo_cheese = df_cheese[df_cheese['promo'] == 'promo']['quantity'].sum()
all_cheese = df_cheese['quantity'].sum()
print(f'{round(promo_cheese/all_cheese * 100, 2)}% от общих продаж категории Сыры занимают промо')
# Out:
# 30.7% от общих продаж категории Сыры занимают промо

# %%
fig, ax = plt.subplots(figsize = (6,6))

ax.xaxis.set_visible(False)

labels = ['по акции', 'всего продано']
ax.pie([promo_cheese,all_cheese],
       colors = [max_color,others],
       explode = [0, 0.1],
       labels = labels,
       autopct= lambda x: f"{x * (sum([promo_cheese,all_cheese])/100):.0f}")
ax.set_title('Доля промо в категории Сыры', fontsize=16,
              fontweight='bold')
plt.show()

# %% [markdown]
# # **Маржа по категориям**
#
# В рублях
# <br>В %

# %%
df_margine_raw = df_merged_raw.loc[:, ['category','quantity', 'price', 'cost_price']]

# %%
df_margine_raw.head(3)
# Out:
#              category  quantity  price  cost_price
# 0  Рыбная гастрономия         1    169          74
# 1  Рыбная гастрономия         1    169          74
# 2  Рыбная гастрономия         1    169          74

# %%
def get_margine(row):
  row['revenue'] = row['quantity'] * row['price']
  row['outlay'] = row['quantity'] * row['cost_price']
  return row

# %%
df_margine = df_margine_raw.apply(lambda x: get_margine(x), axis=1)
df_margine.head(3)
# Out:
#              category  quantity  price  cost_price  revenue  outlay
# 0  Рыбная гастрономия         1    169          74      169      74
# 1  Рыбная гастрономия         1    169          74      169      74
# 2  Рыбная гастрономия         1    169          74      169      74

# %%
df_margine = df_margine.groupby(['category'])[['revenue','outlay']].agg('sum').reset_index()

# %%
df_margine['margine_rub'] = df_margine.apply(lambda x: x['revenue'] - x['outlay'], axis=1)
df_margine['margine_pct'] = df_margine.apply(lambda x: round(x['margine_rub'] / x['revenue']*100, 2), axis=1)
df_margine = df_margine.sort_values(by = 'margine_rub', ascending=False)
df_margine_pct = df_margine.sort_values(by = 'margine_pct', ascending=False)
df_margine
# Out:
#                         category  revenue  outlay  margine_rub  margine_pct
# 0                        unknown    51304   30217        21087        41.10
# 2         Безалкогольные напитки    46107   25734        20373        44.19
# 11                     Кулинария    40840   22388        18452        45.18
# 7         Замороженная продукция    27714   14615        13099        47.26
# 12            Молочная продукция    37582   25089        12493        33.24
# 14            Мясная гастрономия    24150   13920        10230        42.36
# 22                         Снэки    22477   12895         9582        42.63
# 20                  Свежие овощи    33222   24216         9006        27.11
# 1                        Бакалея    21766   13589         8177        37.57
# 21                 Свежие фрукты    27009   19130         7879        29.17
# 24                          Сыры    19824   12350         7474        37.70
# 13   Мучные кондитерские изделия    13904    7621         6283        45.19
# 26  Хлеб и хлебобулочные изделия    14724    8473         6251        42.45
# 8           Кондитерские изделия    13942    8024         5918        42.45
# 17                         Птица    22349   17196         5153        23.06
# 10                   Кофе, какао     9761    4702         5059        51.83
# 9      Консервированные продукты    10101    5947         4154        41.12
# 4                        Гигиена    10055    7084         2971        29.55
# 27                           Чай     6413    3484         2929        45.67
# 19            Рыбная гастрономия     7894    5129         2765        35.03
# 15                          Мясо     8051    5901         2150        26.70
# 5                Детское питание     5091    3274         1817        35.69
# 3                  Бытовая химия     5478    4037         1441        26.31
# 16        Продукция для животных     4157    3044         1113        26.77
# 25                          Уход     4174    3075         1099        26.33
# 18                          Рыба     3460    2439         1021        29.51
# 28                 Яичные товары     4419    3638          781        17.67
# 6       Детство (Гигиена и Уход)     1729    1212          517        29.90
# 23           Специальное питание      410     202          208        50.73

# %%
#создаем обасть графика
fig, (ax1,ax2) = plt.subplots(1,2, figsize = (12,9))

# добавим цвета значениям
df_margine_pct['colours_pct'] = df_margine_pct.apply(lambda x: max_color if x['margine_pct']>40.00 else others, axis = 1)
df_margine['colours_rub'] = df_margine.apply(lambda x: max_color if x['margine_rub']>10500 else others, axis = 1)

#строим левый график
bars1 = ax1.barh(df_margine['category'],
                df_margine['margine_rub'],
                color = df_margine['colours_rub'])
#убираем границы
ax1.xaxis.set_visible(False)
ax1.spines[['right', 'top', 'bottom']].set_visible(False)

#подпишем название
ax1.set_title('Маржа по категориям товаров \nв рублях', fontsize=16,
              fontweight='bold', loc = 'left', pad = 15.0)

# подпишем столбцы
ax1.bar_label(bars1, padding = 5)

#чтоб не менять сортировку в датафрэйме поменяем на оси y
ax1.invert_yaxis()

# строим правый график
bars2 = ax2.barh(df_margine_pct['category'],
                df_margine_pct['margine_pct'],
                color = df_margine_pct['colours_pct'])
#убираем границы
ax2.xaxis.set_visible(False)
ax2.spines[['right', 'top', 'bottom']].set_visible(False)
#подпишем название
ax2.set_title('Маржа по категориям товаров \nв процентах', fontsize=16,
              fontweight='bold', loc = 'left', pad = 15.0)

# подпишем столбцы
ax2.bar_label(bars2, padding = 5, fmt='%.2f%%')
#чтоб не менять сортировку в датафрэйме поменяем на оси y
ax2.invert_yaxis()
#добавим расстояние между графиками
plt.subplots_adjust(wspace = 0.7)
# убираем перекрытие между графиками
plt.tight_layout()
plt.show()

# %% [markdown]
# # **ABC анализ**
#
# Сделайте ABC-анализ продаж по количеству
#
# Сделайте ABC-анализ по сумме продаж

# %%
df_ABC_raw = df
# Out:
#                         category  revenue  outlay  margine_rub  margine_pct  \
# 0                        unknown    51304   30217        21087        41.10
# 2         Безалкогольные напитки    46107   25734        20373        44.19
# 11                     Кулинария    40840   22388        18452        45.18
# 7         Замороженная продукция    27714   14615        13099        47.26
# 12            Молочная продукция    37582   25089        12493        33.24
# 14            Мясная гастрономия    24150   13920        10230        42.36
# 22                         Снэки    22477   12895         9582        42.63
# 20                  Свежие овощи    33222   24216         9006        27.11
# 1                        Бакалея    21766   13589         8177        37.57
# 21                 Свежие фрукты    27009   19130         7879        29.17
# 24                          Сыры    19824   12350         7474        37.70
# 13   Мучные кондитерские изделия    13904    7621         6283        45.19
# 26  Хлеб и хлебобулочные изделия    14724    8473         6251        42.45
# 8           Кондитерские изделия    13942    8024         5918        42.45
# 17                         Птица    22349   17196         5153        23.06
# 10                   Кофе, какао     9761    4702         5059        51.83
# 9      Консервированные продукты    10101    5947         4154        41.12
# 4                        Гигиена    10055    7084         2971        29.55
# 27                           Чай     6413    3484         2929        45.67
# 19            Рыбная гастрономия     7894    5129         2765        35.03
# 15                          Мясо     8051    5901         2150        26.70
# 5                Детское питание     5091    3274         1817        35.69
# 3                  Бытовая химия     5478    4037         1441        26.31
# 16        Продукция для животных     4157    3044         1113        26.77
# 25                          Уход     4174    3075         1099        26.33
# 18                          Рыба     3460    2439         1021        29.51
# 28                 Яичные товары     4419    3638          781        17.67
# 6       Детство (Гигиена и Уход)     1729    1212          517        29.90
# 23           Специальное питание      410     202          208        50.73
#
#    colours_rub
# 0       orchid
# 2       orchid
# 11      orchid
# 7       orchid
# 12      orchid
# 14        gray
# 22        gray
# 20        gray
# 1         gray
# 21        gray
# 24        gray
# 13        gray
# 26        gray
# 8         gray
# 17        gray
# 10        gray
# 9         gray
# 4         gray
# 27        gray
# 19        gray
# 15        gray
# 5         gray
# 3         gray
# 16        gray
# 25        gray
# 18        gray
# 28        gray
# 6         gray
# 23        gray
